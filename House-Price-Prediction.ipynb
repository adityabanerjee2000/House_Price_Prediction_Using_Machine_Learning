# %%
import numpy as np
import pandas as pd
import math

# %%
data = pd.read_csv("Bengaluru_House_Data.csv")

# %%
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.shape
# Out:
# (13320, 9)

# %%
pd.set_option('display.float_format', lambda x: '%.3f'%x)

# %%
data.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
for column in data.columns:
    print(data[column].value_counts())
    print("*"*20)
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64
# ********************
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 15-Aug               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: availability, Length: 81, dtype: int64
# ********************
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# ...

# %%
data.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
data.drop(columns=['area_type','availability','society','balcony'],inplace=True)

# %%
data.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056 2.000  39.070
# 1          Chikka Tirupathi  4 Bedroom       2600 5.000 120.000
# 2               Uttarahalli      3 BHK       1440 2.000  62.000
# 3        Lingadheeranahalli      3 BHK       1521 3.000  95.000
# 4                  Kothanur      2 BHK       1200 2.000  51.000

# %%
data.describe()
# Out:
#            bath     price
# count 13247.000 13320.000
# mean      2.693   112.566
# std       1.341   148.972
# min       1.000     8.000
# 25%       2.000    50.000
# 50%       2.000    72.000
# 75%       3.000   120.000
# max      40.000  3600.000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13319 non-null  object
#  1   size        13304 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13247 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
data['location'].value_counts()
# Out:
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64

# %%
data['location'] = data['location'].fillna('Sarjapur  Road')

# %%
data['size'].value_counts()
# Out:
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# 13 BHK           1
# 12 Bedroom       1
# 27 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# Name: size, dtype: int64

# %%
data['size'] = data['size'].fillna('2 BHK')

# %%
data['bath'].value_counts()
# Out:
# 2.000     6908
# 3.000     3286
# 4.000     1226
# 1.000      788
# 5.000      524
# 6.000      273
# 7.000      102
# 8.000       64
# 9.000       43
# 10.000      13
# 12.000       7
# 13.000       3
# 11.000       3
# 16.000       2
# 27.000       1
# 40.000       1
# 15.000       1
# 14.000       1
# 18.000       1
# Name: bath, dtype: int64

# %%
data['bath'] = data['bath'].fillna(data['bath'].median())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13320 non-null  object
#  1   size        13320 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13320 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
data['bhk'] = data['size'].str.split().str.get(0).astype(int)

# %%
data[data.bhk > 20]
# Out:
#                        location        size total_sqft   bath   price  bhk
# 1718  2Electronic City Phase II      27 BHK       8000 27.000 230.000   27
# 4684                Munnekollal  43 Bedroom       2400 40.000 660.000   43

# %%
data['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
data.head()
# Out:
#                    location       size total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK       1056 2.000  39.070    2
# 1          Chikka Tirupathi  4 Bedroom       2600 5.000 120.000    4
# 2               Uttarahalli      3 BHK       1440 2.000  62.000    3
# 3        Lingadheeranahalli      3 BHK       1521 3.000  95.000    3
# 4                  Kothanur      2 BHK       1200 2.000  51.000    2

# %%
data['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
data['total_sqft'].value_counts()
# Out:
# 1200    843
# 1100    221
# 1500    205
# 2400    196
# 600     180
#        ...
# 3580      1
# 2461      1
# 1437      1
# 2155      1
# 4689      1
# Name: total_sqft, Length: 2117, dtype: int64

# %%
adi = set(data['total_sqft'])

# %%
adi
# Out:
# {'2285',
#  '2480',
#  '3565',
#  '1455',
#  '1801',
#  '350',
#  '3640',
#  '661',
#  '1491',
#  '1999',
#  '1054',
#  '1679',
#  '992',
#  '2031',
#  '2502',
#  '527 - 639',
#  '959',
#  '6830',
#  '905',
#  '250',
#  '4900',
#  '734',
#  '3010',
#  '923',
#  '284',
#  '4100',
#  '3060',
#  '651',
#  '3016',
#  '1654',
#  '1167',
#  '2460',
#  '1550 - 1590',
#  '6600',
#  '1275',
#  '1603',
#  '2437',
#  '1113.12',
#  '1723',
#  '1052 - 1322',
#  '1566',
#  '2462',
#  '1502',
#  '1466',
#  '1440 - 1884',
#  '15',
#  '1690',
#  '1621',
#  '2367',
#  '3190',
#  '1105',
#  '1011',
#  '3815',
#  '5200',
#  '2372',
#  '4408',
#  '706 - 716',
#  '1632',
#  '2026',
#  '896.9',
#  '3729',
#  '1518',
#  '1152',
#  '86.72Sq. Meter',
#  '5080',
#  '870',
#  '4856',
#  '1635',
#  '3161',
#  '2005',
#  '1393',
#  '1465',
#  '400',
#  '1305',
#  '1437',
#  '3913',
#  '4166',
#  '944',
#  '829',
#  '1140 - 1250',
#  '4111',
#  '2107',
#  '2409',
#  '1349',
#  '2533',
#  '1688.12',
#  '4395',
# ...

# %%
def convertRange(x):
    temp = x.split(' - ')
    if(len(temp) ==2):
        return(float(temp[0]) + float(temp[1]))/2
    try:
        return(float(x))
    except:
        return(None)

# %%
print(convertRange('684 - 810'))
# Out:
# 747.0

# %%
data['total_sqft'] = data['total_sqft'].apply(convertRange)

# %%
data.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK    1056.000 2.000  39.070    2
# 1          Chikka Tirupathi  4 Bedroom    2600.000 5.000 120.000    4
# 2               Uttarahalli      3 BHK    1440.000 2.000  62.000    3
# 3        Lingadheeranahalli      3 BHK    1521.000 3.000  95.000    3
# 4                  Kothanur      2 BHK    1200.000 2.000  51.000    2

# %%
data.isna().sum()
# Out:
# location       0
# size           0
# total_sqft    46
# bath           0
# price          0
# bhk            0
# dtype: int64

# %%
data['total_sqft'].value_counts()
# Out:
# 1200.000    843
# 1100.000    221
# 1500.000    206
# 2400.000    196
# 600.000     180
#            ...
# 3080.000      1
# 787.000       1
# 6613.000      1
# 502.000       1
# 4689.000      1
# Name: total_sqft, Length: 1999, dtype: int64

# %%
data['total_sqft'] = data['total_sqft'].fillna(1200.0)

# %%
data.isna().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# bhk           0
# dtype: int64

# %% [markdown]
# # Price Per Squere Feet

# %%
data['price_per_sqft'] = data['price'] * 100000 / data['total_sqft']

# %%
data['price_per_sqft']
# Out:
# 0        3699.811
# 1        4615.385
# 2        4305.556
# 3        6245.891
# 4        4250.000
#            ...
# 13315    6689.835
# 13316   11111.111
# 13317    5258.545
# 13318   10407.336
# 13319    3090.909
# Name: price_per_sqft, Length: 13320, dtype: float64

# %%
data.describe()
# Out:
#        total_sqft      bath     price       bhk  price_per_sqft
# count   13320.000 13320.000 13320.000 13320.000       13320.000
# mean     1558.385     2.689   112.566     2.803        7921.887
# std      1236.445     1.339   148.972     1.294      106247.357
# min         1.000     1.000     8.000     1.000         267.830
# 25%      1100.000     2.000    50.000     2.000        4266.667
# 50%      1275.000     2.000    72.000     3.000        5440.000
# 75%      1678.000     3.000   120.000     3.000        7331.341
# max     52272.000    40.000  3600.000    43.000    12000000.000

# %%
data.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK    1056.000 2.000  39.070    2
# 1          Chikka Tirupathi  4 Bedroom    2600.000 5.000 120.000    4
# 2               Uttarahalli      3 BHK    1440.000 2.000  62.000    3
# 3        Lingadheeranahalli      3 BHK    1521.000 3.000  95.000    3
# 4                  Kothanur      2 BHK    1200.000 2.000  51.000    2
#
#    price_per_sqft
# 0        3699.811
# 1        4615.385
# 2        4305.556
# 3        6245.891
# 4        4250.000

# %%
data['location'].value_counts()
# Out:
# Whitefield                        540
# Sarjapur  Road                    400
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64

# %%
data['location'] = data['location'].apply(lambda x: x.strip())
location_count = data['location'].value_counts()

# %%
location_count
# Out:
# Whitefield                        541
# Sarjapur  Road                    400
# Electronic City                   304
# Kanakpura Road                    273
# Thanisandra                       237
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1294, dtype: int64

# %%
location_count_less_10 = location_count[location_count<=10]
location_count_less_10
# Out:
# Dairy Circle                      10
# Nagappa Reddy Layout              10
# Basapura                          10
# 1st Block Koramangala             10
# Sector 1 HSR Layout               10
#                                   ..
# Bapuji Layout                      1
# 1st Stage Radha Krishna Layout     1
# BEML Layout 5th stage              1
# singapura paradise                 1
# Abshot Layout                      1
# Name: location, Length: 1053, dtype: int64

# %%
data['location'] = data['location'].apply(lambda x: 'other' if x in location_count_less_10 else x)

# %%
data['location'].value_counts()
# Out:
# other                 2885
# Whitefield             541
# Sarjapur  Road         400
# Electronic City        304
# Kanakpura Road         273
#                       ...
# Nehru Nagar             11
# Banjara Layout          11
# LB Shastri Nagar        11
# Pattandur Agrahara      11
# Narayanapura            11
# Name: location, Length: 242, dtype: int64

# %% [markdown]
# # Outlier detection and removal

# %%
data.describe()
# Out:
#        total_sqft      bath     price       bhk  price_per_sqft
# count   13320.000 13320.000 13320.000 13320.000       13320.000
# mean     1558.385     2.689   112.566     2.803        7921.887
# std      1236.445     1.339   148.972     1.294      106247.357
# min         1.000     1.000     8.000     1.000         267.830
# 25%      1100.000     2.000    50.000     2.000        4266.667
# 50%      1275.000     2.000    72.000     3.000        5440.000
# 75%      1678.000     3.000   120.000     3.000        7331.341
# max     52272.000    40.000  3600.000    43.000    12000000.000

# %% [markdown]
# # How much sqft in 1BHK

# %%
(data['total_sqft']/data['bhk']).describe()
# Out:
# count   13320.000
# mean      575.002
# std       388.066
# min         0.250
# 25%       473.000
# 50%       552.500
# 75%       625.000
# max     26136.000
# dtype: float64

# %%
data = data[((data['total_sqft']/data['bhk']) >= 300)]
data.describe()
# Out:
#        total_sqft      bath     price       bhk  price_per_sqft
# count   12568.000 12568.000 12568.000 12568.000       12568.000
# mean     1593.372     2.559   111.410     2.650        6315.243
# std      1259.549     1.078   151.917     0.977        4178.335
# min       300.000     1.000     8.440     1.000         267.830
# 25%      1117.750     2.000    49.000     2.000        4210.280
# 50%      1300.000     2.000    70.000     3.000        5295.545
# 75%      1700.000     3.000   115.000     3.000        6927.325
# max     52272.000    16.000  3600.000    16.000      176470.588

# %%
data.shape
# Out:
# (12568, 7)

# %%
data.price_per_sqft.describe()
# Out:
# count    12568.000
# mean      6315.243
# std       4178.335
# min        267.830
# 25%       4210.280
# 50%       5295.545
# 75%       6927.325
# max     176470.588
# Name: price_per_sqft, dtype: float64

# %% [markdown]
# # Here max: 176470.588 is an outlier

# %%
def remove_outliers_sqft(df):
    df_output = pd.DataFrame()
    for key,subdf in df.groupby('location'):
        m = np.mean(subdf.price_per_sqft)
        
        st = np.std(subdf.price_per_sqft)
        
        gen_df = subdf[(subdf.price_per_sqft > (m-st)) & (subdf.price_per_sqft <= (m+st))]
        df_output = pd.concat([df_output,gen_df],ignore_index = True)
    return df_output
data = remove_outliers_sqft(data)
data.describe()
# Out:
#        total_sqft      bath     price       bhk  price_per_sqft
# count   10355.000 10355.000 10355.000 10355.000       10355.000
# mean     1508.453     2.472    91.383     2.575        5665.821
# std       880.450     0.979    86.366     0.898        2274.169
# min       300.000     1.000    10.000     1.000        1250.000
# 25%      1110.000     2.000    49.000     2.000        4244.830
# 50%      1285.000     2.000    67.000     2.000        5179.283
# 75%      1650.000     3.000   100.000     3.000        6445.733
# max     30400.000    16.000  2200.000    16.000       24509.804

# %%
def bhk_outlier_remover(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices, axis='index')

# %%
data = bhk_outlier_remover(data)

# %%
data.shape
# Out:
# (7386, 7)

# %%
data
# Out:
#                   location       size  total_sqft  bath   price  bhk  \
# 0      1st Block Jayanagar      4 BHK    2850.000 4.000 428.000    4
# 1      1st Block Jayanagar      3 BHK    1630.000 3.000 194.000    3
# 2      1st Block Jayanagar      3 BHK    1875.000 2.000 235.000    3
# 3      1st Block Jayanagar      3 BHK    1200.000 2.000 130.000    3
# 4      1st Block Jayanagar      2 BHK    1235.000 2.000 148.000    2
# ...                    ...        ...         ...   ...     ...  ...
# 10346                other      2 BHK    1200.000 2.000  70.000    2
# 10347                other      1 BHK    1800.000 1.000 200.000    1
# 10350                other      2 BHK    1353.000 2.000 110.000    2
# 10351                other  1 Bedroom     812.000 1.000  26.000    1
# 10354                other      4 BHK    3600.000 5.000 400.000    4
#
#        price_per_sqft
# 0           15017.544
# 1           11901.840
# 2           12533.333
# 3           10833.333
# ...

# %%
data.drop(columns=['size','price_per_sqft'], inplace=True)

# %% [markdown]
# # Cleaned Data

# %%
data.head()
# Out:
#               location  total_sqft  bath   price  bhk
# 0  1st Block Jayanagar    2850.000 4.000 428.000    4
# 1  1st Block Jayanagar    1630.000 3.000 194.000    3
# 2  1st Block Jayanagar    1875.000 2.000 235.000    3
# 3  1st Block Jayanagar    1200.000 2.000 130.000    3
# 4  1st Block Jayanagar    1235.000 2.000 148.000    2

# %%
data.to_csv("Cleaned_data.csv",index=False)

# %%
Debaditya = pd.read_csv("Cleaned_data.csv")

# %%
Debaditya.head()
# Out:
#               location  total_sqft  bath   price  bhk
# 0  1st Block Jayanagar    2850.000 4.000 428.000    4
# 1  1st Block Jayanagar    1630.000 3.000 194.000    3
# 2  1st Block Jayanagar    1875.000 2.000 235.000    3
# 3  1st Block Jayanagar    1200.000 2.000 130.000    3
# 4  1st Block Jayanagar    1235.000 2.000 148.000    2

# %%
X = data.drop(columns=['price'])
y = data['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error as mae

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (5908, 4)
# (1478, 4)

# %% [markdown]
# # Applying Linear Regression

# %%
column_trans = make_column_transformer((OneHotEncoder(sparse=False), ['location']),remainder='passthrough')

# %%
scaler = StandardScaler()

# %%
lr = LinearRegression(normalize=True)

# %%
pipe = make_pipeline(column_trans,scaler,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\baner\.pyenv\pyenv-win\versions\3.10.5\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
# ...

# %%
y_pred_lr = pipe.predict(X_test)

# %%
y_pred_lr
# Out:
# array([ 50.06170409,  79.88402451, 111.51103243, ...,  77.47978243,
#         88.03446993,  30.37621201])

# %% [markdown]
# ### Accurecy in Linear Regression

# %%
r2_score(y_test, y_pred_lr)
# Out:
# 0.8595347446681957

# %% [markdown]
# # Applying Lasso Regression

# %%
lasso = Lasso()

# %%
pipe = make_pipeline(column_trans,scaler, lasso)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
y_pred_lasso = pipe.predict(X_test)

# %% [markdown]
# ### Accurecy In Lasso Regression

# %%
r2_score(y_test, y_pred_lasso)
# Out:
# 0.8513167824878014

# %% [markdown]
# # Applying Ridge Regression

# %%
ridge = Ridge()

# %%
pipe = make_pipeline(column_trans,scaler, ridge)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
y_pred_ridge = pipe.predict(X_test)

# %% [markdown]
# ### Accurecy In Ridge Regression

# %%
r2_score(y_test, y_pred_ridge)
# Out:
# 0.860034661741261

# %%
print("Linear Regression Accurec: ",r2_score(y_test, y_pred_lr)*100)
print("Lasso Regression Accurec: ",r2_score(y_test, y_pred_lasso)*100)
print("Ridge Regression Accurec: ",r2_score(y_test, y_pred_ridge)*100)
# Out:
# Linear Regression Accurec:  85.95347446681957
# Lasso Regression Accurec:  85.13167824878013
# Ridge Regression Accurec:  86.0034661741261

# %%
import pickle

# %%
pickle.dump(pipe, open('RidgeModel.pkl','wb'))

# %% [markdown]
# # Calculate RMSE for Linear Regression:

# %%
MSE = np.square(np.subtract(y_test,y_pred_lr)).mean() 
RMSE = math.sqrt(MSE)
MAE = mae(y_test, y_pred_lr)
print("Root Mean Square Error Linear Regression: ",RMSE)
print("Mean Square Error Linear Regression: ",MSE)
print("Mean Absoluate Error Linear Regression: ",MAE)
# Out:
# Root Mean Square Error Linear Regression:  29.818764733248244
# Mean Square Error Linear Regression:  889.1587302168092
# Mean Absoluate Error Linear Regression:  17.58059255252925

# %% [markdown]
# # Calculate RMSE for Lasso Regression:

# %%
MSE = np.square(np.subtract(y_test,y_pred_lasso)).mean() 
RMSE = math.sqrt(MSE)
MAE = mae(y_test, y_pred_lasso)
print("Root Mean Square Error Lasso Regression: ",RMSE)
print("Mean Square Error Lasso Regression: ",MSE)
print("Mean Absoluate Error Lasso Regression: ",MAE)
# Out:
# Root Mean Square Error Lasso Regression:  30.678644530571923
# Mean Square Error Lasso Regression:  941.1792302331907
# Mean Absoluate Error Lasso Regression:  18.62892141973301

# %% [markdown]
# # Calculate RMSE for Ridge Regression:

# %%
MSE = np.square(np.subtract(y_test,y_pred_ridge)).mean() 
RMSE = math.sqrt(MSE)
MAE = mae(y_test, y_pred_ridge)
print("Root Mean Square Error Ridge Regression: ",RMSE)
print("Mean Square Error Ridge Regression: ",MSE)
print("Mean Absoluate Error Ridge Regression: ",MAE)
# Out:
# Root Mean Square Error Ridge Regression:  29.76565481413317
# Mean Square Error Ridge Regression:  885.9942065141291
# Mean Absoluate Error Ridge Regression:  17.5505219583577
